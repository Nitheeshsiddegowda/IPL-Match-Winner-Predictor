# %%
import numpy as np
import pandas as pd

# %%
match= pd.read_csv('matches_updated_ipl_upto_2025.csv')
delivery=pd.read_csv('deliveries_updated_ipl_upto_2025.csv')

# %%
match.head()
# Out:
#     season                                       venue  winner_runs  \
# 0  2007/08                       M Chinnaswamy Stadium        140.0
# 1  2007/08  Punjab Cricket Association Stadium, Mohali         33.0
# 2  2007/08                            Feroz Shah Kotla          NaN
# 3  2007/08                                Eden Gardens          NaN
# 4  2007/08                            Wankhede Stadium          NaN
#
#           umpire2                  toss_winner        date    umpire1  \
# 0     RE Koertzen  Royal Challengers Bangalore  18-04-2008  Asad Rauf
# 1      SL Shastri          Chennai Super Kings  19-04-2008  MR Benson
# 2  GA Pratapkumar             Rajasthan Royals  19-04-2008  Aleem Dar
# 3     K Hariharan              Deccan Chargers  20-04-2008  BF Bowden
# 4       DJ Harper               Mumbai Indians  20-04-2008   SJ Davis
#
#          city                       winner method  \
# 0   Bangalore        Kolkata Knight Riders    NaN
# 1  Chandigarh          Chennai Super Kings    NaN
# 2       Delhi             Delhi Daredevils    NaN
# 3     Kolkata        Kolkata Knight Riders    NaN
# 4      Mumbai  Royal Challengers Bangalore    NaN
#
#                          team1 toss_decision                        team2  \
# 0  Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1              Kings XI Punjab           bat          Chennai Super Kings
# 2             Delhi Daredevils           bat             Rajasthan Royals
# 3        Kolkata Knight Riders           bat              Deccan Chargers
# 4               Mumbai Indians           bat  Royal Challengers Bangalore
#
#    winner_wickets       tv_umpire player_of_match  match_number      id
# 0             NaN       AM Saheba     BB McCullum           1.0  335982
# 1             NaN       RB Tiffin      MEK Hussey           2.0  335983
# 2             9.0       IL Howell     MF Maharoof           3.0  335984
# 3             5.0       Asad Rauf       DJ Hussey           4.0  335986
# 4             5.0  AV Jayaprakash      MV Boucher           5.0  335985

# %%
match.shape
# Out:
# (1169, 18)

# %%
delivery.head()
# Out:
#    matchId  inning  over  ball           batting_team  \
# 0   335982       1     0     1  Kolkata Knight Riders
# 1   335982       1     0     2  Kolkata Knight Riders
# 2   335982       1     0     3  Kolkata Knight Riders
# 3   335982       1     0     4  Kolkata Knight Riders
# 4   335982       1     0     5  Kolkata Knight Riders
#
#                   bowling_team      batsman  non_striker   bowler  \
# 0  Royal Challengers Bangalore   SC Ganguly  BB McCullum  P Kumar
# 1  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
# 2  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
# 3  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
# 4  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extras  isWide  isNoBall  Byes  LegByes  Penalty  \
# 0             0       1     NaN       NaN   NaN      1.0      NaN
# 1             0       0     NaN       NaN   NaN      NaN      NaN
# 2             0       1     1.0       NaN   NaN      NaN      NaN
# 3             0       0     NaN       NaN   NaN      NaN      NaN
# 4             0       0     NaN       NaN   NaN      NaN      NaN
#
#   dismissal_kind player_dismissed  total_runs
# 0            NaN              NaN           1
# 1            NaN              NaN           0
# 2            NaN              NaN           1
# 3            NaN              NaN           0
# 4            NaN              NaN           0

# %%
total_score_df=delivery.groupby(['matchId','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
match_df=match.merge(total_score_df[['matchId','total_runs']],left_on='id',right_on='matchId')

# %%
match_df
# Out:
#        season                                              venue  winner_runs  \
# 0     2007/08                              M Chinnaswamy Stadium        140.0
# 1     2007/08         Punjab Cricket Association Stadium, Mohali         33.0
# 2     2007/08                                   Feroz Shah Kotla          NaN
# 3     2007/08                                       Eden Gardens          NaN
# 4     2007/08                                   Wankhede Stadium          NaN
# ...       ...                                                ...          ...
# 1164     2025  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...          NaN
# 1165     2025  Maharaja Yadavindra Singh International Cricke...          NaN
# 1166     2025  Maharaja Yadavindra Singh International Cricke...         20.0
# 1167     2025                   Narendra Modi Stadium, Ahmedabad          NaN
# 1168     2025                   Narendra Modi Stadium, Ahmedabad          6.0
#
#              umpire2                  toss_winner        date        umpire1  \
# 0        RE Koertzen  Royal Challengers Bangalore  18-04-2008      Asad Rauf
# 1         SL Shastri          Chennai Super Kings  19-04-2008      MR Benson
# 2     GA Pratapkumar             Rajasthan Royals  19-04-2008      Aleem Dar
# 3        K Hariharan              Deccan Chargers  20-04-2008      BF Bowden
# 4          DJ Harper               Mumbai Indians  20-04-2008       SJ Davis
# ...              ...                          ...         ...            ...
# 1164       VK Sharma  Royal Challengers Bengaluru  27-05-2025       MA Gough
# 1165       VK Sharma  Royal Challengers Bengaluru  29-05-2025       MA Gough
# 1166       UV Gandhe               Mumbai Indians  30-05-2025       R Pandit
# 1167     Nitin Menon                 Punjab Kings  01-06-2025    CB Gaffaney
# 1168     Nitin Menon                 Punjab Kings  03-06-2025  J Madanagopal
#
#                 city                       winner method  \
# 0          Bangalore        Kolkata Knight Riders    NaN
# 1         Chandigarh          Chennai Super Kings    NaN
# 2              Delhi             Delhi Daredevils    NaN
# 3            Kolkata        Kolkata Knight Riders    NaN
# 4             Mumbai  Royal Challengers Bangalore    NaN
# ...              ...                          ...    ...
# 1164         Lucknow  Royal Challengers Bengaluru    NaN
# 1165  New Chandigarh  Royal Challengers Bengaluru    NaN
# 1166  New Chandigarh               Mumbai Indians    NaN
# 1167       Ahmedabad                 Punjab Kings    NaN
# 1168       Ahmedabad  Royal Challengers Bengaluru    NaN
#
#                             team1 toss_decision                        team2  \
# 0     Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1                 Kings XI Punjab           bat          Chennai Super Kings
# 2                Delhi Daredevils           bat             Rajasthan Royals
# 3           Kolkata Knight Riders           bat              Deccan Chargers
# 4                  Mumbai Indians           bat  Royal Challengers Bangalore
# ...                           ...           ...                          ...
# 1164         Lucknow Super Giants         field  Royal Challengers Bengaluru
# 1165                 Punjab Kings         field  Royal Challengers Bengaluru
# 1166               Mumbai Indians           bat               Gujarat Titans
# 1167               Mumbai Indians         field                 Punjab Kings
# 1168  Royal Challengers Bengaluru         field                 Punjab Kings
#
#       winner_wickets              tv_umpire player_of_match  match_number  \
# 0                NaN              AM Saheba     BB McCullum           1.0
# 1                NaN              RB Tiffin      MEK Hussey           2.0
# 2                9.0              IL Howell     MF Maharoof           3.0
# 3                5.0              Asad Rauf       DJ Hussey           4.0
# 4                5.0         AV Jayaprakash      MV Boucher           5.0
# ...              ...                    ...             ...           ...
# 1164             6.0              UV Gandhe       JM Sharma          70.0
# 1165             8.0               R Pandit   Suyash Sharma           NaN
# 1166             NaN              VK Sharma       RG Sharma           NaN
# 1167             5.0  KN Ananthapadmanabhan         SS Iyer           NaN
# 1168             NaN            CB Gaffaney       KH Pandya           NaN
#
#            id  matchId  total_runs
# 0      335982   335982         222
# 1      335983   335983         240
# 2      335984   335984         129
# 3      335986   335986         110
# 4      335985   335985         165
# ...       ...      ...         ...
# 1164  1473507  1473507         227
# 1165  1473508  1473508         101
# 1166  1473509  1473509         228
# 1167  1473510  1473510         203
# 1168  1473511  1473511         190
#
# [1169 rows x 20 columns]

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Kolkata Knight Riders', 'Mumbai Indians',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams=[
    'Royal Challengers Bengaluru',
    'Punjab Kings',
    'Kolkata Knight Riders',
    'Mumbai Indians',
    'Rajasthan Royals',
    'Chennai Super Kings',
    'Sunrisers Hyderabad',
    'Delhi Capitals',
    'Lucknow Super Giants',
    'Gujarat Titans']

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['team1'] = match_df['team1'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
match_df['team2'] = match_df['team2'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

match_df['team1'] = match_df['team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['team2'] = match_df['team2'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (1054, 20)

# %%
match_df = match_df[match_df['method'].isna()]

# %%
match_df= match_df[['matchId','city','winner','total_runs']]

# %%
delivery_df= match_df.merge(delivery,on='matchId')

# %%
delivery_df= delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (119963, 22)

# %%
delivery_df['current_score'] = delivery_df.groupby('matchId')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df['balls_left']=126 - ((delivery_df['over']+1)*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         matchId       city                       winner  total_runs_x  inning  \
# 124      335982  Bangalore        Kolkata Knight Riders           222       2
# 125      335982  Bangalore        Kolkata Knight Riders           222       2
# 126      335982  Bangalore        Kolkata Knight Riders           222       2
# 127      335982  Bangalore        Kolkata Knight Riders           222       2
# 128      335982  Bangalore        Kolkata Knight Riders           222       2
# ...         ...        ...                          ...           ...     ...
# 248533  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248534  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248535  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248536  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248537  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
#
#         over  ball                 batting_team                 bowling_team  \
# 124        0     1  Royal Challengers Bangalore        Kolkata Knight Riders
# 125        0     2  Royal Challengers Bangalore        Kolkata Knight Riders
# 126        0     3  Royal Challengers Bangalore        Kolkata Knight Riders
# 127        0     4  Royal Challengers Bangalore        Kolkata Knight Riders
# 128        0     5  Royal Challengers Bangalore        Kolkata Knight Riders
# ...      ...   ...                          ...                          ...
# 248533    19     2                 Punjab Kings  Royal Challengers Bengaluru
# 248534    19     3                 Punjab Kings  Royal Challengers Bengaluru
# 248535    19     4                 Punjab Kings  Royal Challengers Bengaluru
# 248536    19     5                 Punjab Kings  Royal Challengers Bengaluru
# 248537    19     6                 Punjab Kings  Royal Challengers Bengaluru
#
#                batsman  ... isNoBall Byes  LegByes  Penalty  dismissal_kind  \
# 124           R Dravid  ...      NaN  NaN      NaN      NaN             NaN
# 125           W Jaffer  ...      NaN  NaN      NaN      NaN             NaN
# 126           W Jaffer  ...      NaN  NaN      NaN      NaN             NaN
# 127           W Jaffer  ...      NaN  NaN      NaN      NaN             NaN
# 128           R Dravid  ...      NaN  NaN      NaN      NaN             NaN
# ...                ...  ...      ...  ...      ...      ...             ...
# 248533  Shashank Singh  ...      NaN  NaN      NaN      NaN             NaN
# 248534  Shashank Singh  ...      NaN  NaN      NaN      NaN             NaN
# 248535  Shashank Singh  ...      NaN  NaN      NaN      NaN             NaN
# 248536  Shashank Singh  ...      NaN  NaN      NaN      NaN             NaN
# 248537  Shashank Singh  ...      NaN  NaN      NaN      NaN             NaN
#
#         player_dismissed  total_runs_y  current_score  runs_left balls_left
# 124                  NaN             1              1        221        119
# 125                  NaN             1              2        220        118
# 126                  NaN             0              2        220        117
# 127                  NaN             1              3        219        116
# 128                  NaN             1              4        218        115
# ...                  ...           ...            ...        ...        ...
# 248533               NaN             0            162         28          4
# 248534               NaN             6            168         22          3
# 248535               NaN             4            172         18          2
# 248536               NaN             6            178         12          1
# 248537               NaN             6            184          6          0
#
# [119963 rows x 25 columns]

# %%
delivery_df['player_dismissed'] = delivery['player_dismissed']

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(
    lambda x: x if x == "0" else "1"
)

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')

wickets = delivery_df.groupby('matchId')['player_dismissed'].cumsum().values

delivery_df['wickets'] = 10 - wickets
delivery_df.head()
# Out:
#      matchId       city                 winner  total_runs_x  inning  over  \
# 124   335982  Bangalore  Kolkata Knight Riders           222       2     0
# 125   335982  Bangalore  Kolkata Knight Riders           222       2     0
# 126   335982  Bangalore  Kolkata Knight Riders           222       2     0
# 127   335982  Bangalore  Kolkata Knight Riders           222       2     0
# 128   335982  Bangalore  Kolkata Knight Riders           222       2     0
#
#      ball                 batting_team           bowling_team   batsman  ...  \
# 124     1  Royal Challengers Bangalore  Kolkata Knight Riders  R Dravid  ...
# 125     2  Royal Challengers Bangalore  Kolkata Knight Riders  W Jaffer  ...
# 126     3  Royal Challengers Bangalore  Kolkata Knight Riders  W Jaffer  ...
# 127     4  Royal Challengers Bangalore  Kolkata Knight Riders  W Jaffer  ...
# 128     5  Royal Challengers Bangalore  Kolkata Knight Riders  R Dravid  ...
#
#     Byes LegByes  Penalty  dismissal_kind  player_dismissed  total_runs_y  \
# 124  NaN     NaN      NaN             NaN                 0             1
# 125  NaN     NaN      NaN             NaN                 0             1
# 126  NaN     NaN      NaN             NaN                 0             0
# 127  NaN     NaN      NaN             NaN                 0             1
# 128  NaN     NaN      NaN             NaN                 0             1
#
#      current_score  runs_left  balls_left wickets
# 124              1        221         119      10
# 125              2        220         118      10
# 126              2        220         117      10
# 127              3        219         116      10
# 128              4        218         115      10
#
# [5 rows x 26 columns]

# %%
delivery_df.tail()
# Out:
#         matchId       city                       winner  total_runs_x  inning  \
# 248533  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248534  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248535  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248536  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248537  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
#
#         over  ball  batting_team                 bowling_team         batsman  \
# 248533    19     2  Punjab Kings  Royal Challengers Bengaluru  Shashank Singh
# 248534    19     3  Punjab Kings  Royal Challengers Bengaluru  Shashank Singh
# 248535    19     4  Punjab Kings  Royal Challengers Bengaluru  Shashank Singh
# 248536    19     5  Punjab Kings  Royal Challengers Bengaluru  Shashank Singh
# 248537    19     6  Punjab Kings  Royal Challengers Bengaluru  Shashank Singh
#
#         ... Byes LegByes  Penalty  dismissal_kind  player_dismissed  \
# 248533  ...  NaN     NaN      NaN             NaN                 0
# 248534  ...  NaN     NaN      NaN             NaN                 0
# 248535  ...  NaN     NaN      NaN             NaN                 0
# 248536  ...  NaN     NaN      NaN             NaN                 0
# 248537  ...  NaN     NaN      NaN             NaN                 0
#
#         total_runs_y  current_score  runs_left  balls_left wickets
# 248533             0            162         28           4       5
# 248534             6            168         22           3       5
# 248535             4            172         18           2       5
# 248536             6            178         12           1       5
# 248537             6            184          6           0       5
#
# [5 rows x 26 columns]

# %%
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df
# Out:
#         matchId       city                       winner  total_runs_x  inning  \
# 124      335982  Bangalore        Kolkata Knight Riders           222       2
# 125      335982  Bangalore        Kolkata Knight Riders           222       2
# 126      335982  Bangalore        Kolkata Knight Riders           222       2
# 127      335982  Bangalore        Kolkata Knight Riders           222       2
# 128      335982  Bangalore        Kolkata Knight Riders           222       2
# ...         ...        ...                          ...           ...     ...
# 248533  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248534  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248535  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248536  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248537  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
#
#         over  ball                 batting_team                 bowling_team  \
# 124        0     1  Royal Challengers Bangalore        Kolkata Knight Riders
# 125        0     2  Royal Challengers Bangalore        Kolkata Knight Riders
# 126        0     3  Royal Challengers Bangalore        Kolkata Knight Riders
# 127        0     4  Royal Challengers Bangalore        Kolkata Knight Riders
# 128        0     5  Royal Challengers Bangalore        Kolkata Knight Riders
# ...      ...   ...                          ...                          ...
# 248533    19     2                 Punjab Kings  Royal Challengers Bengaluru
# 248534    19     3                 Punjab Kings  Royal Challengers Bengaluru
# 248535    19     4                 Punjab Kings  Royal Challengers Bengaluru
# 248536    19     5                 Punjab Kings  Royal Challengers Bengaluru
# 248537    19     6                 Punjab Kings  Royal Challengers Bengaluru
#
#                batsman  ... Penalty dismissal_kind  player_dismissed  \
# 124           R Dravid  ...     NaN            NaN                 0
# 125           W Jaffer  ...     NaN            NaN                 0
# 126           W Jaffer  ...     NaN            NaN                 0
# 127           W Jaffer  ...     NaN            NaN                 0
# 128           R Dravid  ...     NaN            NaN                 0
# ...                ...  ...     ...            ...               ...
# 248533  Shashank Singh  ...     NaN            NaN                 0
# 248534  Shashank Singh  ...     NaN            NaN                 0
# 248535  Shashank Singh  ...     NaN            NaN                 0
# 248536  Shashank Singh  ...     NaN            NaN                 0
# 248537  Shashank Singh  ...     NaN            NaN                 0
#
#         total_runs_y  current_score  runs_left  balls_left  wickets       crr  \
# 124                1              1        221         119       10  6.000000
# 125                1              2        220         118       10  6.000000
# 126                0              2        220         117       10  4.000000
# 127                1              3        219         116       10  4.500000
# 128                1              4        218         115       10  4.800000
# ...              ...            ...        ...         ...      ...       ...
# 248533             0            162         28           4        5  8.379310
# 248534             6            168         22           3        5  8.615385
# 248535             4            172         18           2        5  8.745763
# 248536             6            178         12           1        5  8.974790
# 248537             6            184          6           0        5  9.200000
#
#               rrr
# 124     11.142857
# 125     11.186441
# 126     11.282051
# 127     11.327586
# 128     11.373913
# ...           ...
# 248533  42.000000
# 248534  44.000000
# 248535  54.000000
# 248536  72.000000
# 248537        inf
#
# [119963 rows x 28 columns]

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         matchId       city                       winner  total_runs_x  inning  \
# 124      335982  Bangalore        Kolkata Knight Riders           222       2
# 125      335982  Bangalore        Kolkata Knight Riders           222       2
# 126      335982  Bangalore        Kolkata Knight Riders           222       2
# 127      335982  Bangalore        Kolkata Knight Riders           222       2
# 128      335982  Bangalore        Kolkata Knight Riders           222       2
# ...         ...        ...                          ...           ...     ...
# 248533  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248534  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248535  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248536  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
# 248537  1473511  Ahmedabad  Royal Challengers Bengaluru           190       2
#
#         over  ball                 batting_team                 bowling_team  \
# 124        0     1  Royal Challengers Bangalore        Kolkata Knight Riders
# 125        0     2  Royal Challengers Bangalore        Kolkata Knight Riders
# 126        0     3  Royal Challengers Bangalore        Kolkata Knight Riders
# 127        0     4  Royal Challengers Bangalore        Kolkata Knight Riders
# 128        0     5  Royal Challengers Bangalore        Kolkata Knight Riders
# ...      ...   ...                          ...                          ...
# 248533    19     2                 Punjab Kings  Royal Challengers Bengaluru
# 248534    19     3                 Punjab Kings  Royal Challengers Bengaluru
# 248535    19     4                 Punjab Kings  Royal Challengers Bengaluru
# 248536    19     5                 Punjab Kings  Royal Challengers Bengaluru
# 248537    19     6                 Punjab Kings  Royal Challengers Bengaluru
#
#                batsman  ... dismissal_kind player_dismissed  total_runs_y  \
# 124           R Dravid  ...            NaN                0             1
# 125           W Jaffer  ...            NaN                0             1
# 126           W Jaffer  ...            NaN                0             0
# 127           W Jaffer  ...            NaN                0             1
# 128           R Dravid  ...            NaN                0             1
# ...                ...  ...            ...              ...           ...
# 248533  Shashank Singh  ...            NaN                0             0
# 248534  Shashank Singh  ...            NaN                0             6
# 248535  Shashank Singh  ...            NaN                0             4
# 248536  Shashank Singh  ...            NaN                0             6
# 248537  Shashank Singh  ...            NaN                0             6
#
#         current_score  runs_left  balls_left  wickets       crr        rrr  \
# 124                 1        221         119       10  6.000000  11.142857
# 125                 2        220         118       10  6.000000  11.186441
# 126                 2        220         117       10  4.000000  11.282051
# 127                 3        219         116       10  4.500000  11.327586
# 128                 4        218         115       10  4.800000  11.373913
# ...               ...        ...         ...      ...       ...        ...
# 248533            162         28           4        5  8.379310  42.000000
# 248534            168         22           3        5  8.615385  44.000000
# 248535            172         18           2        5  8.745763  54.000000
# 248536            178         12           1        5  8.974790  72.000000
# 248537            184          6           0        5  9.200000        inf
#
#        result
# 124         0
# 125         0
# 126         0
# 127         0
# 128         0
# ...       ...
# 248533      0
# 248534      0
# 248535      0
# 248536      0
# 248537      0
#
# [119963 rows x 29 columns]

# %%
final_df=delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                 batting_team                 bowling_team     city  runs_left  \
# 27717  Kolkata Knight Riders  Royal Challengers Bangalore  Kolkata         67
#
#        balls_left  wickets  total_runs_x       crr       rrr  result
# 27717          77        6           135  9.488372  5.220779       1

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
x=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#                        batting_team                 bowling_team       city  \
# 58464              Rajasthan Royals             Delhi Daredevils      Delhi
# 147649               Delhi Capitals          Chennai Super Kings    Chennai
# 219481               Gujarat Titans         Lucknow Super Giants    Lucknow
# 131118        Kolkata Knight Riders               Mumbai Indians    Kolkata
# 234992          Sunrisers Hyderabad        Kolkata Knight Riders    Kolkata
# ...                             ...                          ...        ...
# 213370               Mumbai Indians          Sunrisers Hyderabad     Mumbai
# 201363        Kolkata Knight Riders          Sunrisers Hyderabad    Kolkata
# 248213                 Punjab Kings               Mumbai Indians  Ahmedabad
# 108911             Delhi Daredevils  Royal Challengers Bangalore  Bangalore
# 168485  Royal Challengers Bangalore             Rajasthan Royals     Mumbai
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr
# 58464          83          58        9           152   6.677419   8.586207
# 147649         96          53        7           179   7.432836  10.867925
# 219481        102          66        8           163   6.777778   9.272727
# 131118        197         111        9           210   8.666667  10.648649
# 234992        125          56        6           200   7.031250  13.392857
# ...           ...         ...      ...           ...        ...        ...
# 213370         86          61        6           200  11.593220   8.459016
# 201363         51          14        5           228  10.018868  21.857143
# 248213        131          74        8           203   9.391304  10.621622
# 108911         52          34        3           191   9.697674   9.176471
# 168485         81          66        7           177  10.666667   7.363636
#
# [90848 rows x 9 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    #('step2',RandomForestClassifier())
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\GOWDA01\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7942057062345896

# %%
pipe.predict_proba(x_test)[10]
# Out:
# array([0.486707, 0.513293])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df,matchId,pipe):
    match = x_df[x_df['matchId'] == matchId]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,336034,pipe)
temp_df
# Out:
# Target- 156
#       end_of_over  runs_after_over  wickets_in_over  lose   win
# 4881            1                3                0  50.2  49.8
# 4888            2                8                0  46.4  53.6
# 4894            3                6                0  50.0  50.0
# 4900            4                9                2  45.3  54.7
# 4906            5                5                1  50.4  49.6
# 4912            6                2                1  61.2  38.8
# 4918            7               10                0  57.4  42.6
# 4924            8               11                0  51.8  48.2
# 4930            9                3                0  61.7  38.3
# 4936           10                5                0  67.5  32.5
# 4943           11               13                1  57.9  42.1
# 4949           12               15                0  44.6  55.4
# 4955           13                7                0  47.1  52.9
# 4961           14                8                0  47.7  52.3
# 4967           15                7                0  50.5  49.5
# 4973           16                3                0  62.3  37.7
# 4979           17               13                0  52.6  47.4
# 4985           18                4                0  65.3  34.7
# 4991           19                5                0  81.6  18.4

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-156')

# %%
teams
# Out:
# ['Royal Challengers Bengaluru',
#  'Punjab Kings',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Lucknow Super Giants',
#  'Gujarat Titans']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Kolkata', 'Mumbai', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Lucknow', 'Guwahati', 'Mohali', 'New Chandigarh'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.1

# %%
pickle.dump(pipe, open('pipe.pkl','wb'))
